# %% [markdown]
# Quante evidenze archeologiche di epoca romana sono presenti in Italia?

# %% [markdown]
# Curiosando sul [Catalogo generale dei Beni Culturali](https://catalogo.beniculturali.it/) mi aspettavo di trovare una risposta ma non è stato così. Già solo accedendo al portale, senza applicare nessun tipo di filtro, effettuando uno zoom sull'area dei Campi Flegrei mi ritrovo nella situazione che segue.

# %% [markdown]
# <p align="center">
#   <img width="100%" height="800px" src="zoom_campi_flegrei.png">
# </p>

# %% [markdown]
# E' presente il solo [Castello di Baia](https://www.campiflegreionline.it/Castello_di_Baia.html) in questa area, secondo il catalogo, ma nella realtà in quest'area possiamo trovare:
# - la [Piscina Mirabilis](https://piscinamirabilisbacoli.it/it)
# - la [Casina Vanvitelliana](https://www.prolococittadibacoli.it/casina-vanvitelliana/)
# - [Baia sommersa](https://www.baiasommersa.it/)
# - il [Tempio di Serapide](http://www.pafleg.it/it/4388/localita/67/macellum-tempio-di-serapide)
# - il [Parco archeologico del Pausilypon](https://www.areamarinaprotettagaiola.it/pausilypon)
#
# Solo per citare i luoghi che conosco per averli visitati direttamente, ma ce ne sono tanti altri.

# %% [markdown]
# Così ho deciso di usare i superpoteri di Python e [OpenStreetMap](https://www.openstreetmap.org/) per darmi una risposta.

# %% [markdown]
# ## Prima di iniziare

# %% [markdown]
# ### Librerie
# Per raggiungere l'obiettivo userò le librerie che seguono.

# %%
from pathlib import Path
import geopandas as gpd
import pandas as pd
from matplotlib import pyplot as plt
import contextily as cx
import osmnx as ox

# %% [markdown]
# ### Fonti dati
# Oltre ai dati di OpenStreetMap userò i confini comunali generalizzati 2023 rilasciati da ISTAT.

# %%
main_folder = Path.cwd().parent.parent.parent.parent.joinpath('sample_data')
municipalities = main_folder.joinpath('Com01012023_g').joinpath('Com01012023_g_WGS84.shp')
regions = main_folder.joinpath('Reg01012023_g').joinpath('Reg01012023_g_WGS84.shp')

osm_crs = 4326

municipalities_gdf = gpd.read_file(municipalities).to_crs(osm_crs)
regions_gdf = gpd.read_file(regions).to_crs(osm_crs)

# %% [markdown]
# Come vedremo in seguito tornerà molto utile conoscere la tassonomia di OpenStreetMap, tassonomia disponibile [qui](https://wiki.openstreetmap.org/wiki/Map_features).

# %% [markdown]
# ## Rimozione dei warnings
# Il codice che segue serve solo per eliminare i messaggi di warning che renderebbero antiestetico l'articolo. **Attenzione ad ignorarli però!** Vanno ben approfonditi e non ignorati alla leggera. Io lo faccio solo perchè questo è un articolo dimostrativo.

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# ## Contenuti
# - [1. Lavoriamo in piccolo: Bacoli](#1.-Lavoriamo-in-piccolo:-Bacoli)
# - [2. Ricerca a scala regionale: Campania](#2.-Ricerca-a-scala-regionale:-Campania)
# - [3. Ricerca a scala nazionale](#3.-Ricerca-a-scala-nazionale)
# - [Conclusione](#Conclusione)

# %% [markdown]
# # 1. Lavoriamo in piccolo: Bacoli
# Partiremo con l'analizzare l'area di Bacoli.

# %%
bacoli = municipalities_gdf[municipalities_gdf['COMUNE']=='Bacoli'].squeeze()
bacoli
# Out:
# COD_RIP                                                       4
# COD_REG                                                      15
# COD_PROV                                                     63
# COD_CM                                                      263
# COD_UTS                                                     263
# PRO_COM                                                   63006
# PRO_COM_T                                                063006
# COMUNE                                                   Bacoli
# COMUNE_A                                                    NaN
# CC_UTS                                                        0
# Shape_Leng                                         20303.054123
# geometry      POLYGON ((14.06724657892957 40.842943679557926...
# Name: 5138, dtype: object

# %% [markdown]
# Interrogheremo il database di OpenStreetMap usando [OSMnx](https://osmnx.readthedocs.io/en/stable/index.html) libreria che (cito dal sito del progetto) *is a Python package to download, model, analyze, and visualize street networks and other geospatial features from OpenStreetMap*. Andremo in particolare ad usare il TAG **historic** con alcune eccezioni che vedremo.

# %%
# %%time

bacoli_data = ox.features_from_polygon(
    polygon=bacoli.geometry,
    tags={'historic': True}
)

bacoli_data
# Out:
# CPU times: user 101 ms, sys: 0 ns, total: 101 ms
# Wall time: 99.9 ms
#                                     historic  \
# element_type osmid
# node         1045290525  archaeological_site
#              1104926219  archaeological_site
#              1139094827  archaeological_site
#              1139094838  archaeological_site
#              1706624371  archaeological_site
#              2235447677                ruins
#              2235447711             memorial
#              2235447893             memorial
#              8755033944                ruins
#              9060732167                ruins
# way          124092891   archaeological_site
#              124093354   archaeological_site
#              144917231                castle
#              240100401   archaeological_site
#              323122081              building
#              406222066   archaeological_site
#              429218964   archaeological_site
#              429324871   archaeological_site
#              429338160   archaeological_site
#              429339087   archaeological_site
#              429340403   archaeological_site
#              429341185   archaeological_site
#              429341186   archaeological_site
#              429341188   archaeological_site
#              429341189   archaeological_site
#              429341190   archaeological_site
#              736686146              building
#              736686737   archaeological_site
#              736690821   archaeological_site
#              1154634667  archaeological_site
#
#                                                      name   wikidata  \
# element_type osmid
# node         1045290525                 Piscina Mirabilis    Q222410
#              1104926219   Grotte dell'Acqua - Lago Fusaro        NaN
#              1139094827            Grotta della Dragonara  Q55673920
#              1139094838           Sacello degli Augustali   Q3944423
#              1706624371                 Grotta di Cocceio    Q518104
#              2235447677                               NaN        NaN
#              2235447711                            Bunker        NaN
#              2235447893                            Bunker        NaN
#              8755033944                    Tempo di Iside        NaN
#              9060732167                               NaN        NaN
# way          124092891   Parco Archeologico Terme di Baia   Q3685188
#              124093354                 Anfiteatro di Cuma  Q93976746
#              144917231         Castello Aragonese di Baia   Q3662303
#              240100401                 Tomba di Agrippina        NaN
#              323122081               Casina Vanvitelliana    Q958152
#              406222066                    Tempio di Diana        NaN
#              429218964                          Columbari        NaN
#              429324871            Monumental Park of Baia        NaN
#              429338160                 Tempio di Mercurio        NaN
#              429339087                   Tempio di Venere  Q96694237
#              429340403                                NaN        NaN
#              429341185                                NaN        NaN
#              429341186                                NaN        NaN
#              429341188                                NaN        NaN
#              429341189                                NaN        NaN
#              429341190                                NaN        NaN
#              736686146                                NaN        NaN
#              736686737                                NaN        NaN
#              736690821                                NaN        NaN
#              1154634667          Teatro romano di Misenum  Q55685837
#
#                                                  wikipedia  \
# element_type osmid
# node         1045290525               en:Piscina Mirabilis
#              1104926219                                NaN
#              1139094827                                NaN
#              1139094838         it:Sacello degli Augustali
#              1706624371                                NaN
#              2235447677                                NaN
#              2235447711                                NaN
#              429340403                          NaN
#              429341185                          NaN
#              429341186                          NaN
#              429341188                          NaN
#              429341189                          NaN
#              429341190                          NaN
#              736686146                          NaN
#              736686737                          NaN
#              736690821                          NaN
#              1154634667                         NaN
#
# [30 rows x 35 columns]

# %%
bacoli_site_count = len(bacoli_data.index)

bacoli_site_count
# Out:
# 30

# %% [markdown]
# Come si può vedere in quest'area ci sono ben 30 siti di interesse archeologico, molti più dei tre che conosco che fanno parte dell'elenco di inizio articolo.
#
# Ma veniamo ai TAG di nostro interesse. Analizzando l'elenco delle [chiavi](https://wiki.openstreetmap.org/wiki/Map_features#Historic) ce ne sono alcune che non mi interessano e le inserirò nella viriabile che segue perchè a me interessano solo le strutture o i resti di strutture.

# %%
excluded_keys = ['aircraft', 'aircraft; memorial', 'anchor', 'battlefield', 'bomb_crater', 'boundary_stone', 'cannon', 'cattle_crush', 'district', 'highwater_mark', 'hotel', 'locomotive', 'memorial', 'ogham_stone', 'railway', 'railway_car', 'railway_station', 'road', 'shieling', 'ship', 'tank', 'vehicle', 'wayside_cross', 'wayside_shrine', 'wreck', 'yes']

excluded_keys
# Out:
# ['aircraft',
#  'aircraft; memorial',
#  'anchor',
#  'battlefield',
#  'bomb_crater',
#  'boundary_stone',
#  'cannon',
#  'cattle_crush',
#  'district',
#  'highwater_mark',
#  'hotel',
#  'locomotive',
#  'memorial',
#  'ogham_stone',
#  'railway',
#  'railway_car',
#  'railway_station',
#  'road',
#  'shieling',
#  'ship',
#  'tank',
#  'vehicle',
#  'wayside_cross',
#  'wayside_shrine',
#  'wreck',
#  'yes']

# %% [markdown]
# Inoltre escluderò anche alcune colonne dal dataset primario in modo da restringere ulteriormente il campo.

# %%
bacoli_data = bacoli_data[['historic', 'name', 'historic:civilization', 'geometry']]
bacoli_data = bacoli_data[~bacoli_data['historic'].isin(excluded_keys)]
bacoli_data = bacoli_data[bacoli_data['name'].notna()]
bacoli_data.reset_index(inplace=True)

bacoli_data
# Out:
#    element_type       osmid             historic  \
# 0          node  1045290525  archaeological_site
# 1          node  1104926219  archaeological_site
# 2          node  1139094827  archaeological_site
# 3          node  1139094838  archaeological_site
# 4          node  1706624371  archaeological_site
# 5          node  8755033944                ruins
# 6           way   124092891  archaeological_site
# 7           way   124093354  archaeological_site
# 8           way   144917231               castle
# 9           way   240100401  archaeological_site
# 10          way   323122081             building
# 11          way   406222066  archaeological_site
# 12          way   429218964  archaeological_site
# 13          way   429324871  archaeological_site
# 14          way   429338160  archaeological_site
# 15          way   429339087  archaeological_site
# 16          way  1154634667  archaeological_site
#
#                                 name  \
# 0                  Piscina Mirabilis
# 1    Grotte dell'Acqua - Lago Fusaro
# 2             Grotta della Dragonara
# 3            Sacello degli Augustali
# 4                  Grotta di Cocceio
# 5                     Tempo di Iside
# 6   Parco Archeologico Terme di Baia
# 7                 Anfiteatro di Cuma
# 8         Castello Aragonese di Baia
# 9                 Tomba di Agrippina
# 10              Casina Vanvitelliana
# 11                   Tempio di Diana
# 12                         Columbari
# 13           Monumental Park of Baia
# 14                Tempio di Mercurio
# 15                  Tempio di Venere
# 16          Teatro romano di Misenum
#
#                         historic:civilization  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4   ancient_roman_-_Augustus_Emperator_period
# 5                                         NaN
# 6                               ancient_roman
# 7                               ancient_roman
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                              ancient_roman
#
#                                              geometry
# 0                           POINT (14.08028 40.79519)
# 1                           POINT (14.05955 40.82506)
# 2                           POINT (14.08506 40.78477)
# 3                           POINT (14.08460 40.78747)
# 4                           POINT (14.06211 40.84534)
# 5                           POINT (14.05002 40.84415)
# 6   POLYGON ((14.07084 40.81923, 14.07072 40.81929...
# 7   POLYGON ((14.05636 40.84248, 14.05598 40.84255...
# 8   POLYGON ((14.08025 40.81003, 14.08046 40.81018...
# 9   POLYGON ((14.08145 40.80291, 14.08133 40.80294...
# 10  POLYGON ((14.05844 40.81979, 14.05847 40.81983...
# 11  POLYGON ((14.07065 40.81926, 14.07043 40.81923...
# 12  POLYGON ((14.06482 40.81952, 14.06543 40.81914...
# 13  POLYGON ((14.07125 40.81337, 14.07098 40.81320...
# 14  POLYGON ((14.06978 40.81790, 14.06982 40.81792...
# 15  POLYGON ((14.07139 40.81624, 14.07152 40.81627...
# 16  POLYGON ((14.08315 40.78788, 14.08303 40.78776...

# %% [markdown]
# Purtroppo a causa del fatto che la colonna *historic:civilization* non è corrattamente campita non riuscirò a sfruttare correttamente i dati a disposizione per rispondere alla mia domanda iniziale, ma meglio di niente. Alcuni siti come la **Piscina Mirabilis** sono di epoca romana ma questo non viene indicato nella colonna in questione per cui se pure volessi filtrare i dati cercando `roman` con la funzione `str.contains` di [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html?highlight=contains#pandas.Series.str.contains) otterei meno dati del previsto. E' un peccato perchè sotto ` Rome` [OpenStreetMap](https://wiki.openstreetmap.org/wiki/Key:historic:civilization#Rome) ha un bel po' di possibilità di ricerca potendo filtrare i dati in base ai vari periodi in cui si è sviluppata la civiltà romana antica.

# %% [markdown]
# Come avrete sicuramente notato, il dataset ha geometrie miste. Di seguito lo normalizzerò per fare in modo da avere solo punti.

# %%
bacoli_polygons = bacoli_data[bacoli_data['element_type']=='way']

bacoli_polygons
# Out:
#    element_type       osmid             historic  \
# 6           way   124092891  archaeological_site
# 7           way   124093354  archaeological_site
# 8           way   144917231               castle
# 9           way   240100401  archaeological_site
# 10          way   323122081             building
# 11          way   406222066  archaeological_site
# 12          way   429218964  archaeological_site
# 13          way   429324871  archaeological_site
# 14          way   429338160  archaeological_site
# 15          way   429339087  archaeological_site
# 16          way  1154634667  archaeological_site
#
#                                 name historic:civilization  \
# 6   Parco Archeologico Terme di Baia         ancient_roman
# 7                 Anfiteatro di Cuma         ancient_roman
# 8         Castello Aragonese di Baia                   NaN
# 9                 Tomba di Agrippina                   NaN
# 10              Casina Vanvitelliana                   NaN
# 11                   Tempio di Diana                   NaN
# 12                         Columbari                   NaN
# 13           Monumental Park of Baia                   NaN
# 14                Tempio di Mercurio                   NaN
# 15                  Tempio di Venere                   NaN
# 16          Teatro romano di Misenum         ancient_roman
#
#                                              geometry
# 6   POLYGON ((14.07084 40.81923, 14.07072 40.81929...
# 7   POLYGON ((14.05636 40.84248, 14.05598 40.84255...
# 8   POLYGON ((14.08025 40.81003, 14.08046 40.81018...
# 9   POLYGON ((14.08145 40.80291, 14.08133 40.80294...
# 10  POLYGON ((14.05844 40.81979, 14.05847 40.81983...
# 11  POLYGON ((14.07065 40.81926, 14.07043 40.81923...
# 12  POLYGON ((14.06482 40.81952, 14.06543 40.81914...
# 13  POLYGON ((14.07125 40.81337, 14.07098 40.81320...
# 14  POLYGON ((14.06978 40.81790, 14.06982 40.81792...
# 15  POLYGON ((14.07139 40.81624, 14.07152 40.81627...
# 16  POLYGON ((14.08315 40.78788, 14.08303 40.78776...

# %%
bacoli_polygons['centroid'] = bacoli_polygons.geometry.centroid
bacoli_polygons.drop(columns={'geometry'}, inplace=True)
bacoli_polygons.rename(columns={'centroid': 'geometry'}, inplace=True)

bacoli_polygons
# Out:
# /tmp/ipykernel_27147/311082464.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   bacoli_polygons['centroid'] = bacoli_polygons.geometry.centroid
# /home/max/.cache/pypoetry/virtualenvs/pygis_blog-iPs2SW5R-py3.10/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_27147/311082464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bacoli_polygons.drop(columns={'geometry'}, inplace=True)
# /tmp/ipykernel_27147/311082464.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bacoli_polygons.rename(columns={'centroid': 'geometry'}, inplace=True)
#    element_type       osmid             historic  \
# 6           way   124092891  archaeological_site
# 7           way   124093354  archaeological_site
# 8           way   144917231               castle
# 9           way   240100401  archaeological_site
# 10          way   323122081             building
# 11          way   406222066  archaeological_site
# 12          way   429218964  archaeological_site
# 13          way   429324871  archaeological_site
# 14          way   429338160  archaeological_site
# 15          way   429339087  archaeological_site
# 16          way  1154634667  archaeological_site
#
#                                 name historic:civilization  \
# 6   Parco Archeologico Terme di Baia         ancient_roman
# 7                 Anfiteatro di Cuma         ancient_roman
# 8         Castello Aragonese di Baia                   NaN
# 9                 Tomba di Agrippina                   NaN
# 10              Casina Vanvitelliana                   NaN
# 11                   Tempio di Diana                   NaN
# 12                         Columbari                   NaN
# 13           Monumental Park of Baia                   NaN
# 14                Tempio di Mercurio                   NaN
# 15                  Tempio di Venere                   NaN
# 16          Teatro romano di Misenum         ancient_roman
#
#                      geometry
# 6   POINT (14.07024 40.81724)
# 7   POINT (14.05604 40.84199)
# 8   POINT (14.08032 40.81106)
# 9   POINT (14.08128 40.80285)
# 10  POINT (14.05842 40.81971)
# 11  POINT (14.07056 40.81914)
# 12  POINT (14.06500 40.81928)
# 13  POINT (14.07141 40.81283)
# 14  POINT (14.06987 40.81782)
# 15  POINT (14.07152 40.81612)
# 16  POINT (14.08313 40.78778)

# %%
bacoli_final = pd.concat([bacoli_polygons, bacoli_data[bacoli_data['element_type']=='node']])
bacoli_final.drop(columns={'element_type'}, inplace=True)
bacoli_final.sort_values(by='name', inplace=True)
bacoli_final = gpd.GeoDataFrame(bacoli_final, geometry='geometry')

bacoli_final
# Out:
#          osmid             historic                              name  \
# 7    124093354  archaeological_site                Anfiteatro di Cuma
# 10   323122081             building              Casina Vanvitelliana
# 8    144917231               castle        Castello Aragonese di Baia
# 12   429218964  archaeological_site                         Columbari
# 2   1139094827  archaeological_site            Grotta della Dragonara
# 4   1706624371  archaeological_site                 Grotta di Cocceio
# 1   1104926219  archaeological_site   Grotte dell'Acqua - Lago Fusaro
# 13   429324871  archaeological_site           Monumental Park of Baia
# 6    124092891  archaeological_site  Parco Archeologico Terme di Baia
# 0   1045290525  archaeological_site                 Piscina Mirabilis
# 3   1139094838  archaeological_site           Sacello degli Augustali
# 16  1154634667  archaeological_site          Teatro romano di Misenum
# 11   406222066  archaeological_site                   Tempio di Diana
# 14   429338160  archaeological_site                Tempio di Mercurio
# 15   429339087  archaeological_site                  Tempio di Venere
# 5   8755033944                ruins                    Tempo di Iside
# 9    240100401  archaeological_site                Tomba di Agrippina
#
#                         historic:civilization                   geometry
# 7                               ancient_roman  POINT (14.05604 40.84199)
# 10                                        NaN  POINT (14.05842 40.81971)
# 8                                         NaN  POINT (14.08032 40.81106)
# 12                                        NaN  POINT (14.06500 40.81928)
# 2                                         NaN  POINT (14.08506 40.78477)
# 4   ancient_roman_-_Augustus_Emperator_period  POINT (14.06211 40.84534)
# 1                                         NaN  POINT (14.05955 40.82506)
# 13                                        NaN  POINT (14.07141 40.81283)
# 6                               ancient_roman  POINT (14.07024 40.81724)
# 0                                         NaN  POINT (14.08028 40.79519)
# 3                                         NaN  POINT (14.08460 40.78747)
# 16                              ancient_roman  POINT (14.08313 40.78778)
# 11                                        NaN  POINT (14.07056 40.81914)
# 14                                        NaN  POINT (14.06987 40.81782)
# 15                                        NaN  POINT (14.07152 40.81612)
# 5                                         NaN  POINT (14.05002 40.84415)
# 9                                         NaN  POINT (14.08128 40.80285)

# %% [markdown]
# Ora che il dataset è di soli punti cerchiamo di rispondere a qualche domanda.

# %% [markdown]
# ## 1.1. Come sono raggruppati i siti?

# %%
bacoli_group = bacoli_final.groupby(by='historic').count()
bacoli_group.drop(columns={'name', 'historic:civilization', 'geometry'}, inplace=True)
bacoli_group.rename(columns={'osmid': 'count'}, inplace=True)
bacoli_group.sort_values(by='count', ascending=False, inplace=True)

bacoli_group
# Out:
#                      count
# historic
# archaeological_site     14
# building                 1
# castle                   1
# ruins                    1

# %% [markdown]
# ## 1.2. Dove sono localizzati i soli siti archeologici?

# %%
contextily_tile_crs = 3857
target_data = 'archaeological_site'
bacoli_archaeological_site = bacoli_final[bacoli_final['historic']==target_data]

bacoli_polygon = gpd.GeoDataFrame(geometry=gpd.GeoSeries(bacoli.geometry), crs=osm_crs).to_crs(contextily_tile_crs)


b_minx, b_miny, b_maxx, b_maxy = bacoli_polygon.squeeze().bounds

bacoli_img, bacoli_ext = cx.bounds2img(w=b_minx, s=b_miny, e=b_maxx, n=b_maxy, ll=False)

fig, ax = plt.subplots(figsize=(10, 10))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.suptitle('Comune di Bacoli')
plt.title(f'Siti archeologici: {len(bacoli_archaeological_site.index)}')

ax.imshow(bacoli_img, extent=bacoli_ext, zorder=0)
bacoli_polygon.boundary.plot(ax=ax, edgecolor='black', zorder=1)
bacoli_archaeological_site.to_crs(contextily_tile_crs).plot(ax=ax, marker="o", facecolor='red', edgecolor='white', markersize=50, zorder=2)
# Out:
# <Axes: title={'center': 'Siti archeologici: 14'}>

# %% [markdown]
# # 2. Ricerca a scala regionale: Campania
#
# Ripetiamo l'analisi ma a scala regionale in modo da ottenere i dati che ci consentiranno di dare le risposte alle stesse domande fatte per Bacoli.

# %%
campania = regions_gdf[regions_gdf['DEN_REG']=='Campania'].squeeze()

campania
# Out:
# COD_RIP                                                       4
# COD_REG                                                      15
# DEN_REG                                                Campania
# Shape_Leng                                         888166.70685
# Shape_Area                                   13663252600.799999
# geometry      MULTIPOLYGON (((15.294678222474477 40.02369364...
# Name: 14, dtype: object

# %%
# %%time

campania_data = ox.features_from_polygon(
    polygon=campania.geometry,
    tags={'historic': True}
)

campania_data
# Out:
# CPU times: user 4.91 s, sys: 44.9 ms, total: 4.95 s
# Wall time: 4.95 s
#                          historic  \
# element_type osmid
# node         1233738646     ruins
#              1234013962    castle
#              1278425106     ruins
#              1456773590     ruins
#              1601204543  monument
# ...                           ...
# way          1105039541     ruins
#              1109860259    castle
#              1119447938  building
#              1120991526  building
# relation     10557325      castle
#
#                                                                   geometry  \
# element_type osmid
# node         1233738646                          POINT (15.51893 40.07559)
#              1234013962                          POINT (15.55494 40.13962)
#              1278425106                          POINT (15.42702 40.27348)
#              1456773590                          POINT (15.36115 39.99905)
#              1601204543                          POINT (15.32197 40.15126)
# ...                                                                    ...
# way          1105039541  POLYGON ((13.88314 41.12800, 13.88307 41.12790...
#              1109860259  POLYGON ((14.25132 41.36490, 14.25159 41.36487...
#              1119447938  POLYGON ((14.15338 41.26210, 14.15339 41.26206...
#              1120991526  POLYGON ((14.22349 41.27448, 14.22348 41.27437...
# relation     10557325    POLYGON ((13.93373 41.23848, 13.93372 41.23847...
#
#                                                              name religion  \
# element_type osmid
# node         1233738646                                       NaN      NaN
#              1234013962                                       NaN      NaN
#              1278425106                                       NaN      NaN
#              1456773590                          Torre dell'Isola      NaN
#              1601204543           Chiesa di San Marco Evangelista      NaN
# ...                                                           ...      ...
# way          1105039541                                       NaN      NaN
#              1109860259                                Rupecanina      NaN
#              1119447938                       Torre dell'orologio      NaN
#              1120991526  Scuola Municipale Storica di Roccaromana      NaN
# relation     10557325                             Castello ducale      NaN
#
#                         access name:bg name:it alt_name archaeological_site  \
# element_type osmid
# node         1233738646    NaN     NaN     NaN      NaN                 NaN
#              1234013962    NaN     NaN     NaN      NaN                 NaN
#              1278425106    NaN     NaN     NaN      NaN                 NaN
#              1456773590    NaN     NaN     NaN      NaN                 NaN
#              1601204543    NaN     NaN     NaN      NaN                 NaN
# ...                        ...     ...     ...      ...                 ...
# way          1105039541    NaN     NaN     NaN      NaN                 NaN
#              1109860259    NaN     NaN     NaN      NaN                 NaN
#              1119447938    NaN     NaN     NaN      NaN                 NaN
#              1120991526    NaN     NaN     NaN      NaN                 NaN
# relation     10557325      NaN     NaN     NaN      NaN                 NaN
#
#                            addr:city  ... old_name operator:type disused pump  \
# element_type osmid                    ...
# node         1233738646          NaN  ...      NaN           NaN     NaN  NaN
#              1234013962          NaN  ...      NaN           NaN     NaN  NaN
#              1278425106          NaN  ...      NaN           NaN     NaN  NaN
#              1456773590          NaN  ...      NaN           NaN     NaN  NaN
#              1601204543          NaN  ...      NaN           NaN     NaN  NaN
# ...                              ...  ...      ...           ...     ...  ...
# way          1105039541          NaN  ...      NaN           NaN     NaN  NaN
#              1109860259          NaN  ...      NaN           NaN     NaN  NaN
#              1119447938          NaN  ...      NaN           NaN     NaN  NaN
#              1120991526  Roccaromana  ...      NaN           NaN     NaN  NaN
# relation     10557325            NaN  ...      NaN           NaN     NaN  NaN
#
#                         defensive description:de description:en  \
# element_type osmid
# node         1233738646       NaN            NaN            NaN
#              1234013962       NaN            NaN            NaN
#              1278425106       NaN            NaN            NaN
#              1456773590       NaN            NaN            NaN
#              1601204543       NaN            NaN            NaN
# ...                           ...            ...            ...
# way          1105039541       NaN            NaN            NaN
#              1109860259       NaN            NaN            NaN
#              1119447938       NaN            NaN            NaN
#              1120991526       NaN            NaN            NaN
# relation     10557325         NaN            NaN            NaN
#
#                         disused:railway hazard trail_visibility
# element_type osmid
# node         1233738646             NaN    NaN              NaN
#              1234013962             NaN    NaN              NaN
#              1278425106             NaN    NaN              NaN
#              1456773590             NaN    NaN              NaN
#              1601204543             NaN    NaN              NaN
# ...                                 ...    ...              ...
# way          1105039541             NaN    NaN              NaN
#              1109860259             NaN    NaN              NaN
#              1119447938             NaN    NaN              NaN
#              1120991526             NaN    NaN              NaN
# relation     10557325               NaN    NaN              NaN
#
# [3480 rows x 215 columns]

# %%
campania_data = campania_data[['historic', 'name', 'historic:civilization', 'geometry']]
campania_data = campania_data[~campania_data['historic'].isin(excluded_keys)]
campania_data = campania_data[campania_data['name'].notna()]
campania_data.reset_index(inplace=True)

campania_data
# Out:
#      element_type       osmid  historic  \
# 0            node  1456773590     ruins
# 1            node  1601204543  monument
# 2            node  1704137785  monument
# 3            node  1711457809     ruins
# 4            node  1967471831  monument
# ...           ...         ...       ...
# 1803          way  1090715537     ruins
# 1804          way  1109860259    castle
# 1805          way  1119447938  building
# 1806          way  1120991526  building
# 1807     relation    10557325    castle
#
#                                           name historic:civilization  \
# 0                             Torre dell'Isola                   NaN
# 1              Chiesa di San Marco Evangelista                   NaN
# 2      Casa del Canonico Antonio Maria De Luca                   NaN
# 3                          Cappella S. Michele                   NaN
# 4                                      Christo                   NaN
# ...                                        ...                   ...
# 1803          Rovine del Castello di Caianello                   NaN
# 1804                                Rupecanina                   NaN
# 1805                       Torre dell'orologio                   NaN
# 1806  Scuola Municipale Storica di Roccaromana                   NaN
# 1807                           Castello ducale                   NaN
#
#                                                geometry
# 0                             POINT (15.36115 39.99905)
# 1                             POINT (15.32197 40.15126)
# 2                             POINT (15.40496 40.09458)
# 3                             POINT (15.37871 40.09500)
# 4                             POINT (15.35784 40.06201)
# ...                                                 ...
# 1803  POLYGON ((14.08538 41.29496, 14.08553 41.29500...
# 1804  POLYGON ((14.25132 41.36490, 14.25159 41.36487...
# 1805  POLYGON ((14.15338 41.26210, 14.15339 41.26206...
# 1806  POLYGON ((14.22349 41.27448, 14.22348 41.27437...
# 1807  POLYGON ((13.93373 41.23848, 13.93372 41.23847...
#
# [1808 rows x 6 columns]

# %%
campania_polygons = campania_data[campania_data['element_type']=='way']

campania_polygons
# Out:
#      element_type       osmid             historic  \
# 18            way   103970321               castle
# 19            way   109673812               castle
# 20            way   111289472  archaeological_site
# 21            way   144525571               castle
# 22            way   232953215             building
# ...           ...         ...                  ...
# 1802          way  1034620667                ruins
# 1803          way  1090715537                ruins
# 1804          way  1109860259               castle
# 1805          way  1119447938             building
# 1806          way  1120991526             building
#
#                                           name historic:civilization  \
# 18              Torre (Castello degli Antichi)                   NaN
# 19                      Castello di Policastro                   NaN
# 20                  Sito archeologico di Molpa                   NaN
# 21                            Palazzo Baronale                   NaN
# 22                              Palazzo Ducale                   NaN
# ...                                        ...                   ...
# 1802                            rocca Dragonis                   NaN
# 1803          Rovine del Castello di Caianello                   NaN
# 1804                                Rupecanina                   NaN
# 1805                       Torre dell'orologio                   NaN
# 1806  Scuola Municipale Storica di Roccaromana                   NaN
#
#                                                geometry
# 18    POLYGON ((15.67241 40.33869, 15.67253 40.33868...
# 19    POLYGON ((15.52128 40.07844, 15.52157 40.07790...
# 20    POLYGON ((15.30344 40.03226, 15.30374 40.03207...
# 21    POLYGON ((15.67943 40.21478, 15.67957 40.21472...
# 22    POLYGON ((15.33727 40.33529, 15.33720 40.33496...
# ...                                                 ...
# 1802  POLYGON ((13.89958 41.13091, 13.89942 41.13064...
# 1803  POLYGON ((14.08538 41.29496, 14.08553 41.29500...
# 1804  POLYGON ((14.25132 41.36490, 14.25159 41.36487...
# 1805  POLYGON ((14.15338 41.26210, 14.15339 41.26206...
# 1806  POLYGON ((14.22349 41.27448, 14.22348 41.27437...
#
# [1127 rows x 6 columns]

# %%
campania_polygons['centroid'] = campania_polygons.geometry.centroid
campania_polygons.drop(columns={'geometry'}, inplace=True)
campania_polygons.rename(columns={'centroid': 'geometry'}, inplace=True)

campania_polygons
# Out:
# /tmp/ipykernel_27147/3675524279.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   campania_polygons['centroid'] = campania_polygons.geometry.centroid
# /home/max/.cache/pypoetry/virtualenvs/pygis_blog-iPs2SW5R-py3.10/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_27147/3675524279.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   campania_polygons.drop(columns={'geometry'}, inplace=True)
# /tmp/ipykernel_27147/3675524279.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   campania_polygons.rename(columns={'centroid': 'geometry'}, inplace=True)
#      element_type       osmid             historic  \
# 18            way   103970321               castle
# 19            way   109673812               castle
# 20            way   111289472  archaeological_site
# 21            way   144525571               castle
# 22            way   232953215             building
# ...           ...         ...                  ...
# 1802          way  1034620667                ruins
# 1803          way  1090715537                ruins
# 1804          way  1109860259               castle
# 1805          way  1119447938             building
# 1806          way  1120991526             building
#
#                                           name historic:civilization  \
# 18              Torre (Castello degli Antichi)                   NaN
# 19                      Castello di Policastro                   NaN
# 20                  Sito archeologico di Molpa                   NaN
# 21                            Palazzo Baronale                   NaN
# 22                              Palazzo Ducale                   NaN
# ...                                        ...                   ...
# 1802                            rocca Dragonis                   NaN
# 1803          Rovine del Castello di Caianello                   NaN
# 1804                                Rupecanina                   NaN
# 1805                       Torre dell'orologio                   NaN
# 1806  Scuola Municipale Storica di Roccaromana                   NaN
#
#                        geometry
# 18    POINT (15.67246 40.33864)
# 19    POINT (15.52158 40.07822)
# 20    POINT (15.30370 40.03271)
# 21    POINT (15.67941 40.21455)
# 22    POINT (15.33695 40.33505)
# ...                         ...
# 1802  POINT (13.89960 41.13073)
# 1803  POINT (14.08543 41.29480)
# 1804  POINT (14.25164 41.36472)
# 1805  POINT (14.15341 41.26209)
# 1806  POINT (14.22353 41.27442)
#
# [1127 rows x 6 columns]

# %%
campania_final = pd.concat([campania_polygons, campania_data[campania_data['element_type']=='node']])
campania_final.drop(columns={'element_type'}, inplace=True)
campania_final.sort_values(by='name', inplace=True)
campania_final = gpd.GeoDataFrame(campania_final, geometry='geometry')

campania_final
# Out:
#            osmid             historic                                    name  \
# 745   2119655941             monument                      150° Anni d'Italia
# 292    435717995            monastery                      Abbazia del Goleto
# 94    4947822441                ruins  Abitato di acropoli - edificio arcaico
# 123    222321463             monument                              Acquedotto
# 1707   845154928               bridge                              Acquedotto
# ...          ...                  ...                                     ...
# 1099   505054347                 tomb                            unknown tomb
# 1097   505054345                 tomb                            unknown tomb
# 433   7036790307                ruins                         vecchia calcara
# 1703   802580354  archaeological_site                           via Domitiana
# 1746  5378404295                ruins                            villa romana
#
#      historic:civilization                   geometry
# 745                    NaN  POINT (14.34131 41.07334)
# 292                    NaN  POINT (15.14352 40.90592)
# 94                     NaN  POINT (15.27648 40.25771)
# 123                    NaN  POINT (15.26815 40.24818)
# 1707                   NaN  POINT (14.26074 40.87512)
# ...                    ...                        ...
# 1099                   NaN  POINT (14.48051 40.75207)
# 1097                   NaN  POINT (14.48061 40.75202)
# 433                    NaN  POINT (14.74056 40.68214)
# 1703         ancient_roman  POINT (14.05667 40.85108)
# 1746                   NaN  POINT (14.21883 41.18651)
#
# [1733 rows x 5 columns]

# %%
campania_site_count = len(campania_final.index)

campania_site_count
# Out:
# 1733

# %% [markdown]
# Sulla base dei dati contenuti in OpenStreetMap e dei TAG di ricerca inseriti, risulta che in Campania ci sono 1733 siti di interesse storico-archeologico.

# %% [markdown]
# ## 2.1. Come sono raggruppati i siti?

# %%
campania_group = campania_final.groupby(by='historic').count()
campania_group.drop(columns={'name', 'historic:civilization', 'geometry'}, inplace=True)
campania_group.rename(columns={'osmid': 'count'}, inplace=True)
campania_group.sort_values(by='count', ascending=False, inplace=True)

campania_group
# Out:
#                                   count
# historic
# archaeological_site                 577
# ruins                               365
# monument                            229
# castle                              205
# tomb                                100
# heritage                             78
# building                             74
# city_gate                            39
# citywalls                            11
# tower                                10
# bridge                               10
# church                                9
# monastery                             6
# fort                                  4
# farm                                  3
# aqueduct                              3
# roman_road                            2
# village                               1
# acqueduct                             1
# gate                                  1
# prison                                1
# milestone                             1
# lavoir                                1
# archaelogical_site;mine;aqueduct      1
# windmill                              1

# %% [markdown]
# ## 2.2. Dove sono localizzati i soli siti archeologici?

# %%
campania_polygon = gpd.GeoDataFrame(geometry=gpd.GeoSeries(campania.geometry), crs=osm_crs).to_crs(contextily_tile_crs)
campania_archaeological_site = campania_final[campania_final['historic']==target_data]

c_minx, c_miny, c_maxx, c_maxy = campania_polygon.squeeze().bounds

campania_img, campania_ext = cx.bounds2img(w=c_minx, s=c_miny, e=c_maxx, n=c_maxy, ll=False)

fig2, ax2 = plt.subplots(figsize=(10, 10))
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)
plt.suptitle('Campania')
plt.title(f'Siti archeologici: {len(campania_archaeological_site.index)}')

ax2.imshow(campania_img, extent=campania_ext, zorder=0)
campania_polygon.boundary.plot(ax=ax2, edgecolor='black', zorder=1)
campania_archaeological_site.to_crs(contextily_tile_crs).plot(ax=ax2, marker="o", facecolor='red', edgecolor='white', markersize=50, zorder=2)
# Out:
# <Axes: title={'center': 'Siti archeologici: 14'}>

# %% [markdown]
# # 3. Ricerca a scala nazionale
#
# Tutto come al punto *2* ma a scala nazionale.

# %%
italia = regions_gdf.dissolve().squeeze()

italia
# Out:
# geometry      MULTIPOLYGON (((8.41239408066858 38.8612742703...
# COD_RIP                                                       1
# COD_REG                                                       1
# DEN_REG                                                Piemonte
# Shape_Leng                                        1236799.83183
# Shape_Area                                   25393881930.299999
# Name: 0, dtype: object

# %%
# %%time

italia_data = ox.features_from_polygon(
    polygon=italia.geometry,
    tags={'historic': True}
)

italia_data
# Out:
# CPU times: user 3min 54s, sys: 9.82 s, total: 4min 4s
# Wall time: 4min 4s
#                                historic  \
# element_type osmid
# node         7868747286        memorial
#              465242664         memorial
#              910358621    wayside_cross
#              910561763    wayside_cross
#              1149564353           ruins
# ...                                 ...
# way          792170382              yes
#              792170989              yes
#              889030470            ruins
#              889257442   wayside_shrine
#              1080515646           ruins
#
#                                                                       name  \
# element_type osmid
# node         7868747286  Memoriale vittime del naufragio del 3 ottobre ...
#              465242664                Monumento all'olivicultore Il Sicano
#              910358621                                                 NaN
#              910561763                                                 NaN
#              1149564353                                   Torre Granatelli
# ...                                                                    ...
# way          792170382                                                 NaN
#              792170989                                                 NaN
#              889030470                                                 NaN
#              889257442                                                 NaN
#              1080515646                                      Capanna Gamba
#
#                                                                   geometry  \
# element_type osmid
# node         7868747286                          POINT (12.60751 35.50267)
#              465242664                           POINT (12.81015 37.66188)
#              910358621                           POINT (12.59370 37.66452)
#              910561763                           POINT (12.60369 37.65963)
#              1149564353                          POINT (12.62953 37.69836)
# ...                                                                    ...
# way          792170382   POLYGON ((6.88599 45.68088, 6.88605 45.68092, ...
#              792170989   POLYGON ((6.88611 45.68022, 6.88612 45.68026, ...
#              889030470   LINESTRING (7.14040 45.68853, 7.14047 45.68853...
#              889257442   POLYGON ((7.13543 45.71861, 7.13546 45.71862, ...
#              1080515646  POLYGON ((6.88259 45.80152, 6.88264 45.80153, ...
#
#                         access barrier bicycle foot motorcar motorcycle  \
# element_type osmid
# node         7868747286    NaN     NaN     NaN  NaN      NaN        NaN
#              465242664     NaN     NaN     NaN  NaN      NaN        NaN
#              910358621     NaN     NaN     NaN  NaN      NaN        NaN
#              910561763     NaN     NaN     NaN  NaN      NaN        NaN
#              1149564353    NaN     NaN     NaN  NaN      NaN        NaN
# ...                        ...     ...     ...  ...      ...        ...
# way          792170382     NaN     NaN     NaN  NaN      NaN        NaN
#              792170989     NaN     NaN     NaN  NaN      NaN        NaN
#              889030470     NaN     NaN     NaN  NaN      NaN        NaN
#              889257442     NaN     NaN     NaN  NaN      NaN        NaN
#              1080515646    NaN     NaN     NaN  NaN      NaN        NaN
#
#                         tourism  ... lanes:emergency:conditional  \
# element_type osmid               ...
# node         7868747286     NaN  ...                         NaN
#              465242664      NaN  ...                         NaN
#              910358621      NaN  ...                         NaN
#              910561763      NaN  ...                         NaN
#              1149564353     NaN  ...                         NaN
# ...                         ...  ...                         ...
# way          792170382      NaN  ...                         NaN
#              792170989      NaN  ...                         NaN
#              889030470      NaN  ...                         NaN
#              889257442      NaN  ...                         NaN
#              1080515646     NaN  ...                         NaN
#
#                         bridge:name:fr name:oc source:name:oc  \
# element_type osmid
# node         7868747286            NaN     NaN            NaN
#              465242664             NaN     NaN            NaN
#              910358621             NaN     NaN            NaN
#              910561763             NaN     NaN            NaN
#              1149564353            NaN     NaN            NaN
# ...                                ...     ...            ...
# way          792170382             NaN     NaN            NaN
#              792170989             NaN     NaN            NaN
#              889030470             NaN     NaN            NaN
#              889257442             NaN     NaN            NaN
#              1080515646            NaN     NaN            NaN
#
#                         source:prominence name:frp parking:both  \
# element_type osmid
# node         7868747286               NaN      NaN          NaN
#              465242664                NaN      NaN          NaN
#              910358621                NaN      NaN          NaN
#              910561763                NaN      NaN          NaN
#              1149564353               NaN      NaN          NaN
# ...                                   ...      ...          ...
# way          792170382                NaN      NaN          NaN
#              792170989                NaN      NaN          NaN
#              889030470                NaN      NaN          NaN
#              889257442                NaN      NaN          NaN
#              1080515646               NaN      NaN          NaN
#
#                         trailblazed:visibility mtb:note handrail:left
# element_type osmid
# node         7868747286                    NaN      NaN           NaN
#              465242664                     NaN      NaN           NaN
#              910358621                     NaN      NaN           NaN
#              910561763                     NaN      NaN           NaN
#              1149564353                    NaN      NaN           NaN
# ...                                        ...      ...           ...
# way          792170382                     NaN      NaN           NaN
#              792170989                     NaN      NaN           NaN
#              889030470                     NaN      NaN           NaN
#              889257442                     NaN      NaN           NaN
#              1080515646                    NaN      NaN           NaN
#
# [117983 rows x 1254 columns]

# %%
italia_data = italia_data[['historic', 'name', 'historic:civilization', 'geometry']]
italia_data = italia_data[~italia_data['historic'].isin(excluded_keys)]
italia_data = italia_data[italia_data['name'].notna()]
italia_data.reset_index(inplace=True)

italia_data
# Out:
#       element_type       osmid             historic  \
# 0             node  1149564353                ruins
# 1             node  1149564682                ruins
# 2             node  3878637404  archaeological_site
# 3             node  4479113496                ruins
# 4             node  5965009778  archaeological_site
# ...            ...         ...                  ...
# 28113          way   445667229            watermill
# 28114          way   652952909                ruins
# 28115          way   652952910                ruins
# 28116          way   768670460                ruins
# 28117          way  1080515646                ruins
#
#                                  name historic:civilization  \
# 0                    Torre Granatelli                   NaN
# 1                       Torre Grimesi                   NaN
# 2            Necropoli, Castelvetrano                   NaN
# 3      Santuario di Hera Matrimoniale                   NaN
# 4         Selinunte ingresso Triscina         Ancient_Greek
# ...                               ...                   ...
# 28113          Mulino del Grand-Haury                   NaN
# 28114                      Casermette                modern
# 28115                      Casermette                modern
# 28116                  Ricovero Adami                   NaN
# 28117                   Capanna Gamba                   NaN
#
#                                                 geometry
# 0                              POINT (12.62953 37.69836)
# 1                              POINT (12.72536 37.71378)
# 2                              POINT (12.78983 37.59280)
# 3                              POINT (12.81771 37.58643)
# 4                              POINT (12.81288 37.58463)
# ...                                                  ...
# 28113  POLYGON ((7.13874 45.68356, 7.13875 45.68353, ...
# 28114  POLYGON ((6.90022 45.68080, 6.90025 45.68075, ...
# 28115  POLYGON ((6.89994 45.68062, 6.89994 45.68056, ...
# 28116  POLYGON ((6.99024 45.61458, 6.99030 45.61462, ...
# 28117  POLYGON ((6.88259 45.80152, 6.88264 45.80153, ...
#
# [28118 rows x 6 columns]

# %%
italia_polygons = italia_data[italia_data['element_type']=='way']

italia_polygons
# Out:
#       element_type       osmid   historic                    name  \
# 7              way    34943416      ruins           Arco Normanno
# 8              way    38785368      ruins          Tempio di Hera
# 9              way    58606782      ruins             Patrantonio
# 10             way    58606783      ruins     Baglio Don Federico
# 11             way    58606785      ruins            Baglio Riolo
# ...            ...         ...        ...                     ...
# 28113          way   445667229  watermill  Mulino del Grand-Haury
# 28114          way   652952909      ruins              Casermette
# 28115          way   652952910      ruins              Casermette
# 28116          way   768670460      ruins          Ricovero Adami
# 28117          way  1080515646      ruins           Capanna Gamba
#
#       historic:civilization                                           geometry
# 7                       NaN  POLYGON ((12.59113 37.65041, 12.59112 37.65036...
# 8                       NaN  POLYGON ((12.83445 37.58675, 12.83527 37.58670...
# 9                       NaN  POLYGON ((12.65663 37.61588, 12.65687 37.61558...
# 10                      NaN  POLYGON ((12.51577 37.69994, 12.51596 37.69984...
# 11                      NaN  POLYGON ((12.56747 37.67633, 12.56798 37.67623...
# ...                     ...                                                ...
# 28113                   NaN  POLYGON ((7.13874 45.68356, 7.13875 45.68353, ...
# 28114                modern  POLYGON ((6.90022 45.68080, 6.90025 45.68075, ...
# 28115                modern  POLYGON ((6.89994 45.68062, 6.89994 45.68056, ...
# 28116                   NaN  POLYGON ((6.99024 45.61458, 6.99030 45.61462, ...
# 28117                   NaN  POLYGON ((6.88259 45.80152, 6.88264 45.80153, ...
#
# [15596 rows x 6 columns]

# %%
italia_final = pd.concat([italia_polygons, italia_data[italia_data['element_type']=='node']])
italia_final.drop(columns={'element_type'}, inplace=True)
italia_final.sort_values(by='name', inplace=True)
italia_final = gpd.GeoDataFrame(italia_final, geometry='geometry')

italia_final
# Out:
#              osmid             historic  \
# 21853  10934220626             monument
# 3544    5284179170             monument
# 10515   4119157392             monument
# 25307   6825324511  archaeological_site
# 25670    485182848                ruins
# ...            ...                  ...
# 9969    2661451129  archaeological_site
# 9983     321561427                ruins
# 4924    8344362252   technical_monument
# 22774    225138405                ruins
# 5941    3548335004  archaeological_site
#
#                                                     name  \
# 21853                       "Abbraccio" di Walter Mutton
# 3544                                               "Aia"
# 10515  "Albero inginocchiato" - luogo in cui San Brun...
# 25307                                        "Campanile"
# 25670                                           "Ciappa"
# ...                                                  ...
# 9969                                   zona archeologica
# 9983                                      Àfrico Vecchio
# 4924                             Áncora di Molo Sartorio
# 22774                          Òsini Betzu/Osini Vecchio
# 5941                                             Ακράγας
#
#       historic:civilization                                           geometry
# 21853                   NaN                           POINT (9.06102 45.69856)
# 3544                    NaN                          POINT (13.14895 43.50022)
# 10515                   NaN                          POINT (16.31276 38.55455)
# 25307           prehistoric                           POINT (8.84725 40.42183)
# 25670                   NaN  POLYGON ((8.31572 44.16803, 8.31571 44.16802, ...
# ...                     ...                                                ...
# 9969                    NaN                          POINT (15.95379 37.92615)
# 9983                 modern  POLYGON ((15.97584 38.06419, 15.97706 38.06399...
# 4924                    NaN                          POINT (13.76053 45.64642)
# 22774                   NaN  POLYGON ((9.49217 39.82852, 9.49175 39.82864, ...
# 5941          ancient_greek                          POINT (13.58857 37.29203)
#
# [26554 rows x 5 columns]

# %%
italia_site_count = len(italia_final.index)

italia_site_count
# Out:
# 26554

# %% [markdown]
# Sulla base dei dati contenuti in OpenStreetMap e dei TAG di ricerca inseriti, risulta che in Italia ci sono 26554 siti di interesse storico-archeologico.

# %% [markdown]
# ## 3.1. Come sono raggruppati i siti?

# %%
italia_group = italia_final.groupby(by='historic').count()
italia_group.drop(columns={'name', 'historic:civilization', 'geometry'}, inplace=True)
italia_group.rename(columns={'osmid': 'count'}, inplace=True)
italia_group.sort_values(by='count', ascending=False, inplace=True)

italia_group
# Out:
#                               count
# historic
# archaeological_site            5472
# ruins                          4813
# monument                       4024
# castle                         3055
# building                       1566
# ...                             ...
# former_convent                    1
# footway                           1
# etrusca                           1
# edificio_storico_neoclassico      1
# millstone                         1
#
# [202 rows x 1 columns]

# %% [markdown]
# ## 3.2. Dove sono localizzati i soli siti archeologici?

# %%
italia_polygon = gpd.GeoDataFrame(geometry=gpd.GeoSeries(italia.geometry), crs=osm_crs).to_crs(contextily_tile_crs)
italia_archaeological_site = italia_final[italia_final['historic']==target_data]

minx, miny, maxx, maxy = italia_polygon.squeeze().bounds

italia_img, italia_ext = cx.bounds2img(w=minx, s=miny, e=maxx, n=maxy, ll=False)

fig3, ax3 = plt.subplots(figsize=(10, 10))
ax3.get_xaxis().set_visible(False)
ax3.get_yaxis().set_visible(False)
plt.suptitle('Italia')
plt.title(f'Siti archeologici: {len(italia_archaeological_site.index)}')

ax3.imshow(italia_img, extent=italia_ext, zorder=0)
italia_polygon.boundary.plot(ax=ax3, edgecolor='black', zorder=1)
italia_archaeological_site.to_crs(contextily_tile_crs).plot(ax=ax3, marker="o", facecolor='red', edgecolor='white', markersize=20, zorder=2)
# Out:
# <Axes: title={'center': 'Siti archeologici: 5472'}>

# %% [markdown]
# # Conclusione

# %% [markdown]
# L'analisi appena condotta può dare solo una stima parziale per patrimonio storico-archeologico italiano. Solo i dati ufficiali del Ministero della Cultura possono dare una informazione esatta. Purtroppo i dati ufficiali al momento risultano molto carenti per cui si fa di necessità virtù. Immaginate cosa potrebbe essere realizzato per incentivare, migliorare ed equamente distribuire il turismo in Italia se i dati ufficiali fossero liberamente disponibili. Le metodologie di analisi, come quella appena condotta, esistono ma manca il dato! Manca il dato OPEN!
